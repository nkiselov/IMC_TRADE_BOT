# %%
import importlib

import round1.big_squid_attack as trading
import simulator
importlib.reload(trading)
importlib.reload(simulator)

Trader = trading.Trader
Simulator = simulator.Simulator

trader = Trader()
sim = Simulator(["r1_bad_money.csv"])
# sim = Simulator([
#     "round1data/prices_round_1_day_-2.csv",
#     "round1data/prices_round_1_day_-1.csv",
#     "round1data/prices_round_1_day_0.csv"
# ])
print("RUNNING")
sim.runSimul(trader,True)
# Out:
# RUNNING
# 0
# 30 BUY 10 @ 2035.0
# 34 SELL 10 @ 2032.0
# 36 BUY 10 @ 2035.0
# 45 SELL 10 @ 2032.0
# 48 BUY 10 @ 2035.0
# 66 SELL 10 @ 2032.0
# 80 BUY 10 @ 2035.0
# 98 SELL 10 @ 2032.0
# 101 BUY 5.0 @ 2035.0
# 110 SELL 10 @ 2033.0
# 118 BUY 10 @ 2036.0
# 123 SELL 10 @ 2032.0
# 144 BUY 10 @ 2036.0
# 146 SELL 10 @ 2032.0
# 150 BUY 2.0 @ 2035.0
# 160 SELL 10 @ 2032.0
# 165 BUY 1.0 @ 2035.0
# 188 SELL 10 @ 2033.0
# 205 BUY 10 @ 2036.0
# 211 SELL 10 @ 2033.0
# 212 BUY 10 @ 2036.0
# 213 SELL 10 @ 2033.0
# 219 BUY 10 @ 2036.0
# 221 SELL 10 @ 2032.0
# 225 BUY 10 @ 2036.0
# 235 SELL 10 @ 2033.0
# 237 BUY 10 @ 2036.0
# 241 SELL 10 @ 2033.0
# 259 BUY 10 @ 2036.0
# 278 SELL 10 @ 2033.0
# 294 BUY 10 @ 2036.0
# 296 SELL 10 @ 2033.0
# 300 BUY 10 @ 2036.0
# 303 SELL 10 @ 2033.0
# 304 BUY 10 @ 2037.0
# 309 SELL 10 @ 2033.0
# 310 BUY 10 @ 2036.0
# 311 SELL 10 @ 2033.0
# 313 BUY 10 @ 2037.0
# 314 SELL 10 @ 2033.0
# 315 BUY 10 @ 2037.0
# 332 SELL 1.0 @ 2034.0
# 340 BUY 10 @ 2037.0
# 352 SELL 10 @ 2034.0
# ...
